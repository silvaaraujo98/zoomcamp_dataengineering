# %%
import pandas as pd
from pathlib import Path

# %%
with open("../dados_anac.json", "r") as f:
    primeiros_caracteres = f.read(10000)
    print(f"Conteúdo do início do arquivo: \n{primeiros_caracteres}")
# Out:
# Conteúdo do início do arquivo:
# ...
